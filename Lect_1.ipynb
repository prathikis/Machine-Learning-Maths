# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 40, 1000)  #start,end,no of points

# %%
d_r = 2.5 * t
d_s = 3*(t-5)

# %%
fig,ax = plt.subplots()
plt.title("Time Of Caught")
plt.xlabel('time in mins')
plt.ylabel('dist in kms')
ax.set_xlim([0,40])
ax.set_ylim([0,100])
ax.plot(t,d_r,c='red')
ax.plot(t,d_s,c='blue')
plt.axvline(x=30,color='green',linestyle='--')
plt.axhline(y=75,color='green',linestyle='--')
c_diff = np.abs(d_r - d_s)
i = np.argmin(c_diff)
c_d = np.round(d_r[i])
c_t = np.round(t[i])
plt.plot(caught_time, caught_dist, 'ro')
plt.text(c_t - 17, c_d + 3, f'Caught at {c_d:.0f} kms at {c_t:.0f} mins', color='red')
# Out:
# Text(13.0, 78.0, 'Caught at 75 kms at 30 mins')

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/7ispr/Machine Learning Maths/.git/

# %%
# !git add Lect.ipynb
